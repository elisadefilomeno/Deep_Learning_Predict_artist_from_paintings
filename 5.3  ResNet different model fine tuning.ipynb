# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import os
from tqdm import tqdm, tqdm_notebook
import random
from google.colab import drive
from google.colab import files
import shutil

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from numpy.random import seed
import pickle
seed(1)
tf.random.set_seed(1)

# %%
# mount drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
root_path = "/content/drive/Shareddrives/[Deep Learning Project]"
dataset_dir = os.path.join(root_path, "Dataset")
balanced_train_dir = os.path.join(dataset_dir, 'balanced_train') # We're using the balanced dataset
test_dir = os.path.join(dataset_dir, 'test')

# %%
#Set the parameter used to load the dataset
BATCH_SIZE = 64
IMAGE_HEIGHT = 180
IMAGE_WIDTH = 180

# %% [markdown]
# #Creation of the training, validation and test set
#
# We exploit the directory hierarchy of our dataset to infer the classes from the
# name of the directories, more details are present in the report about the choices taken.

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    balanced_train_dir,
    labels='inferred', 
    label_mode='categorical',
    class_names=None, 
    color_mode='rgb',
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE,
    validation_split=0.1,
    subset="training",
    shuffle=True,
    seed=1024)

validation_dataset = image_dataset_from_directory(
    balanced_train_dir,
    labels='inferred', 
    label_mode='categorical',
    class_names=None, 
    color_mode='rgb',
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE,
    validation_split=0.1,
    subset="validation",
    shuffle=True,
    seed=1024)

test_dataset = image_dataset_from_directory(
    test_dir,
    labels='inferred', 
    label_mode='categorical',
    class_names=None, 
    color_mode='rgb',
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE)
# Out:
# Found 8100 files belonging to 18 classes.
# Using 7290 files for training.
# Found 8100 files belonging to 18 classes.
# Using 810 files for validation.
# Found 1112 files belonging to 18 classes.

# %%
dir_name = os.path.join(root_path, "Models")
if not os.path.exists(dir_name):
  os.makedirs(dir_name)

# %% [markdown]
# Let's import the pre-trained model:

# %%
from tensorflow.keras.applications import resnet_v2

resent_model = resnet_v2.ResNet50V2(include_top=False, weights='imagenet', input_shape=(180, 180, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 0s 0us/step

# %%
resent_model.summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 186, 186, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 90, 90, 64)   9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 92, 92, 64)   0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 45, 45, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 45, 45, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 45, 45, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 45, 45, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 45, 45, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 45, 45, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 45, 45, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 45, 45, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 45, 45, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 45, 45, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 45, 45, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 45, 45, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 45, 45, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 45, 45, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 23, 23, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 23, 23, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 23, 23, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 23, 23, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 23, 23, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 23, 23, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 23, 23, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 23, 23, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 23, 23, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 23, 23, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 23, 23, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 23, 23, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 23, 23, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 12, 12, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 12, 12, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 12, 12, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 12, 12, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 12, 12, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 12, 12, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 12, 12, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 12, 12, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 12, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 12, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 12, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 12, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 6, 6, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 6, 6, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 6, 6, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 6, 6, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 6, 6, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 6, 6, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 6, 6, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 6, 6, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 6, 6, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 6, 6, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 6, 6, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 6, 6, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 6, 6, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 6, 6, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 6, 6, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 23,519,360
# Non-trainable params: 45,440
# __________________________________________________________________________________________________

# %%
import numpy as np

print('This is the number of trainable weights '
      'before freezing the conv base:', sum(np.prod(x.shape) for x in resent_model.trainable_weights))
# Out:
# This is the number of trainable weights before freezing the conv base: 23519360

# %% [markdown]
# # Feature extraction

# %% [markdown]
# Let's freeze all the layers in the convolution base:

# %%
resent_model.trainable = False

# %%
print('This is the number of trainable weights '
      'after freezing the conv base:', sum(np.prod(x.shape) for x in resent_model.trainable_weights))

# Make sure you have frozen the correct layers
for i, layer in enumerate(resent_model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# This is the number of trainable weights after freezing the conv base: 0
# 0 input_1 False
# 1 conv1_pad False
# 2 conv1_conv False
# 3 pool1_pad False
# 4 pool1_pool False
# 5 conv2_block1_preact_bn False
# 6 conv2_block1_preact_relu False
# 7 conv2_block1_1_conv False
# 8 conv2_block1_1_bn False
# 9 conv2_block1_1_relu False
# 10 conv2_block1_2_pad False
# 11 conv2_block1_2_conv False
# 12 conv2_block1_2_bn False
# 13 conv2_block1_2_relu False
# 14 conv2_block1_0_conv False
# 15 conv2_block1_3_conv False
# 16 conv2_block1_out False
# 17 conv2_block2_preact_bn False
# 18 conv2_block2_preact_relu False
# 19 conv2_block2_1_conv False
# 20 conv2_block2_1_bn False
# 21 conv2_block2_1_relu False
# 22 conv2_block2_2_pad False
# 23 conv2_block2_2_conv False
# 24 conv2_block2_2_bn False
# 25 conv2_block2_2_relu False
# 26 conv2_block2_3_conv False
# 27 conv2_block2_out False
# 28 conv2_block3_preact_bn False
# 29 conv2_block3_preact_relu False
# 30 conv2_block3_1_conv False
# 31 conv2_block3_1_bn False
# 32 conv2_block3_1_relu False
# 33 conv2_block3_2_pad False
# 34 conv2_block3_2_conv False
# 35 conv2_block3_2_bn False
# 36 conv2_block3_2_relu False
# 37 max_pooling2d False
# 38 conv2_block3_3_conv False
# 39 conv2_block3_out False
# 40 conv3_block1_preact_bn False
# 41 conv3_block1_preact_relu False
# 42 conv3_block1_1_conv False
# 43 conv3_block1_1_bn False
# 44 conv3_block1_1_relu False
# 45 conv3_block1_2_pad False
# 46 conv3_block1_2_conv False
# 47 conv3_block1_2_bn False
# 48 conv3_block1_2_relu False
# 49 conv3_block1_0_conv False
# 50 conv3_block1_3_conv False
# 51 conv3_block1_out False
# 52 conv3_block2_preact_bn False
# 53 conv3_block2_preact_relu False
# 54 conv3_block2_1_conv False
# 55 conv3_block2_1_bn False
# 56 conv3_block2_1_relu False
# 57 conv3_block2_2_pad False
# 58 conv3_block2_2_conv False
# 59 conv3_block2_2_bn False
# 60 conv3_block2_2_relu False
# 61 conv3_block2_3_conv False
# 62 conv3_block2_out False
# 63 conv3_block3_preact_bn False
# 64 conv3_block3_preact_relu False
# 65 conv3_block3_1_conv False
# 66 conv3_block3_1_bn False
# 67 conv3_block3_1_relu False
# 68 conv3_block3_2_pad False
# 69 conv3_block3_2_conv False
# 70 conv3_block3_2_bn False
# 71 conv3_block3_2_relu False
# 72 conv3_block3_3_conv False
# 73 conv3_block3_out False
# 74 conv3_block4_preact_bn False
# 75 conv3_block4_preact_relu False
# 76 conv3_block4_1_conv False
# 77 conv3_block4_1_bn False
# 78 conv3_block4_1_relu False
# 79 conv3_block4_2_pad False
# 80 conv3_block4_2_conv False
# 81 conv3_block4_2_bn False
# 82 conv3_block4_2_relu False
# 83 max_pooling2d_1 False
# 84 conv3_block4_3_conv False
# 85 conv3_block4_out False
# 86 conv4_block1_preact_bn False
# 87 conv4_block1_preact_relu False
# 88 conv4_block1_1_conv False
# 89 conv4_block1_1_bn False
# 90 conv4_block1_1_relu False
# 91 conv4_block1_2_pad False
# 92 conv4_block1_2_conv False
# 93 conv4_block1_2_bn False
# 94 conv4_block1_2_relu False
# 95 conv4_block1_0_conv False
# 96 conv4_block1_3_conv False
# 97 conv4_block1_out False
# 98 conv4_block2_preact_bn False
# 99 conv4_block2_preact_relu False
# 100 conv4_block2_1_conv False
# 101 conv4_block2_1_bn False
# 102 conv4_block2_1_relu False
# 103 conv4_block2_2_pad False
# 104 conv4_block2_2_conv False
# 105 conv4_block2_2_bn False
# 106 conv4_block2_2_relu False
# 107 conv4_block2_3_conv False
# 108 conv4_block2_out False
# 109 conv4_block3_preact_bn False
# 110 conv4_block3_preact_relu False
# 111 conv4_block3_1_conv False
# 112 conv4_block3_1_bn False
# 113 conv4_block3_1_relu False
# 114 conv4_block3_2_pad False
# 115 conv4_block3_2_conv False
# 116 conv4_block3_2_bn False
# 117 conv4_block3_2_relu False
# 118 conv4_block3_3_conv False
# 119 conv4_block3_out False
# 120 conv4_block4_preact_bn False
# 121 conv4_block4_preact_relu False
# 122 conv4_block4_1_conv False
# 123 conv4_block4_1_bn False
# 124 conv4_block4_1_relu False
# 125 conv4_block4_2_pad False
# 126 conv4_block4_2_conv False
# 127 conv4_block4_2_bn False
# 128 conv4_block4_2_relu False
# 129 conv4_block4_3_conv False
# 130 conv4_block4_out False
# 131 conv4_block5_preact_bn False
# 132 conv4_block5_preact_relu False
# 133 conv4_block5_1_conv False
# 134 conv4_block5_1_bn False
# 135 conv4_block5_1_relu False
# 136 conv4_block5_2_pad False
# 137 conv4_block5_2_conv False
# 138 conv4_block5_2_bn False
# 139 conv4_block5_2_relu False
# 140 conv4_block5_3_conv False
# 141 conv4_block5_out False
# 142 conv4_block6_preact_bn False
# 143 conv4_block6_preact_relu False
# 144 conv4_block6_1_conv False
# 145 conv4_block6_1_bn False
# 146 conv4_block6_1_relu False
# 147 conv4_block6_2_pad False
# 148 conv4_block6_2_conv False
# 149 conv4_block6_2_bn False
# 150 conv4_block6_2_relu False
# 151 max_pooling2d_2 False
# 152 conv4_block6_3_conv False
# 153 conv4_block6_out False
# 154 conv5_block1_preact_bn False
# 155 conv5_block1_preact_relu False
# 156 conv5_block1_1_conv False
# 157 conv5_block1_1_bn False
# 158 conv5_block1_1_relu False
# 159 conv5_block1_2_pad False
# 160 conv5_block1_2_conv False
# 161 conv5_block1_2_bn False
# 162 conv5_block1_2_relu False
# 163 conv5_block1_0_conv False
# 164 conv5_block1_3_conv False
# 165 conv5_block1_out False
# 166 conv5_block2_preact_bn False
# 167 conv5_block2_preact_relu False
# 168 conv5_block2_1_conv False
# 169 conv5_block2_1_bn False
# 170 conv5_block2_1_relu False
# 171 conv5_block2_2_pad False
# 172 conv5_block2_2_conv False
# 173 conv5_block2_2_bn False
# 174 conv5_block2_2_relu False
# 175 conv5_block2_3_conv False
# 176 conv5_block2_out False
# 177 conv5_block3_preact_bn False
# 178 conv5_block3_preact_relu False
# 179 conv5_block3_1_conv False
# 180 conv5_block3_1_bn False
# 181 conv5_block3_1_relu False
# 182 conv5_block3_2_pad False
# 183 conv5_block3_2_conv False
# 184 conv5_block3_2_bn False
# 185 conv5_block3_2_relu False
# 186 conv5_block3_3_conv False
# 187 conv5_block3_out False
# 188 post_bn False
# 189 post_relu False

# %%
from tensorflow.keras import layers

data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

# %% [markdown]
# Now we define the classifier that we will add on top of the convolutional base:

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = resnet_v2.preprocess_input(x)
x = resent_model(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(18, activation="softmax")(x)

optimizer = keras.optimizers.Adam(learning_rate=1e-2)

model = keras.Model(inputs, outputs)
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 180, 180, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 180, 180, 3)      0
#  a)
#
#  resnet50v2 (Functional)     (None, 6, 6, 2048)        23564800
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dropout (Dropout)           (None, 73728)             0
#
#  dense (Dense)               (None, 18)                1327122
#
# =================================================================
# Total params: 24,891,922
# Trainable params: 1,327,122
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %% [markdown]
# **Let's add Keras callbacks:**
# *   Early stopping
# *   ModelCheckpoint
# *   ReduceLROnPlateau

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=12),

    keras.callbacks.ModelCheckpoint(
    filepath=os.path.join(dir_name, 'ResNet_feature_extraction.h5'),
    monitor='val_loss',
    save_best_only=True,
    ),

    keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=5,
    )
]

# %% [markdown]
# Train the network:

# %%
history = model.fit(train_dataset,
                    epochs=100,
                    callbacks=callbacks_list,
                    validation_data=validation_dataset
                    )
# Out:
# Epoch 1/100
# 114/114 [==============================] - 1134s 9s/step - loss: 53.7360 - accuracy: 0.4687 - val_loss: 34.5552 - val_accuracy: 0.6370 - lr: 0.0100
# Epoch 2/100
# 114/114 [==============================] - 35s 291ms/step - loss: 41.6624 - accuracy: 0.6274 - val_loss: 38.6367 - val_accuracy: 0.6728 - lr: 0.0100
# Epoch 3/100
# 114/114 [==============================] - 37s 298ms/step - loss: 39.0709 - accuracy: 0.6815 - val_loss: 32.9952 - val_accuracy: 0.7284 - lr: 0.0100
# Epoch 4/100
# 114/114 [==============================] - 36s 304ms/step - loss: 37.2354 - accuracy: 0.7159 - val_loss: 39.2434 - val_accuracy: 0.7321 - lr: 0.0100
# Epoch 5/100
# 114/114 [==============================] - 34s 285ms/step - loss: 35.2442 - accuracy: 0.7385 - val_loss: 48.8342 - val_accuracy: 0.7012 - lr: 0.0100
# Epoch 6/100
# 114/114 [==============================] - 35s 295ms/step - loss: 35.5846 - accuracy: 0.7550 - val_loss: 38.4390 - val_accuracy: 0.7765 - lr: 0.0100
# Epoch 7/100
# 114/114 [==============================] - 36s 299ms/step - loss: 34.0570 - accuracy: 0.7748 - val_loss: 37.4602 - val_accuracy: 0.7593 - lr: 0.0100
# Epoch 8/100
# 114/114 [==============================] - 36s 289ms/step - loss: 34.9118 - accuracy: 0.7750 - val_loss: 44.7721 - val_accuracy: 0.7444 - lr: 0.0100
# Epoch 9/100
# 114/114 [==============================] - 34s 285ms/step - loss: 28.2797 - accuracy: 0.8071 - val_loss: 35.2800 - val_accuracy: 0.7951 - lr: 1.0000e-03
# Epoch 10/100
# 114/114 [==============================] - 35s 284ms/step - loss: 25.2323 - accuracy: 0.8247 - val_loss: 34.0497 - val_accuracy: 0.7889 - lr: 1.0000e-03
# Epoch 11/100
# 114/114 [==============================] - 37s 307ms/step - loss: 24.7572 - accuracy: 0.8243 - val_loss: 30.0821 - val_accuracy: 0.7975 - lr: 1.0000e-03
# Epoch 12/100
# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

i = np.argmax(val_acc)
x_min = epochs[i]
y_min = val_acc[i]
plt.plot(x_min, y_min,'g',marker='o', label="Maximum validation accuracy")

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

i = np.argmin(val_loss)
x_min = epochs[i]
y_min = val_loss[i]
plt.plot(x_min, y_min,'g',marker='o', label="Minimum validation loss")

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # Fine tuning conv 5:

# %%
filepath=os.path.join(dir_name, 'ResNet_feature_extraction.h5')
model=keras.models.load_model(filepath)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 180, 180, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 180, 180, 3)      0
#  a)
#
#  resnet50v2 (Functional)     (None, 6, 6, 2048)        23564800
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dropout (Dropout)           (None, 73728)             0
#
#  dense (Dense)               (None, 18)                1327122
#
# =================================================================
# Total params: 24,891,922
# Trainable params: 1,327,122
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
model.layers[4].summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 186, 186, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 90, 90, 64)   9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 92, 92, 64)   0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 45, 45, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 45, 45, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 45, 45, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 45, 45, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 45, 45, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 45, 45, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 45, 45, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 45, 45, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 45, 45, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 45, 45, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 45, 45, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 45, 45, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 45, 45, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 45, 45, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 23, 23, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 23, 23, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 23, 23, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 23, 23, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 23, 23, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 23, 23, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 23, 23, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 23, 23, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 23, 23, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 23, 23, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 23, 23, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 23, 23, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 23, 23, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 12, 12, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 12, 12, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 12, 12, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 12, 12, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 12, 12, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 12, 12, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 12, 12, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 12, 12, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 12, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 12, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 12, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 12, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 6, 6, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 6, 6, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 6, 6, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 6, 6, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 6, 6, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 6, 6, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 6, 6, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 6, 6, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 6, 6, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 6, 6, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 6, 6, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 6, 6, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 6, 6, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 6, 6, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 6, 6, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 0
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
model.layers[4].trainable = True
set_trainable = False

for layer in model.layers[4].layers[:154]:
  layer.trainable = False
for layer in model.layers[4].layers[154:]:
  layer.trainable = True

# %%
# Make sure you have frozen the correct layers
for i, layer in enumerate(model.layers[4].layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 False
# 1 conv1_pad False
# 2 conv1_conv False
# 3 pool1_pad False
# 4 pool1_pool False
# 5 conv2_block1_preact_bn False
# 6 conv2_block1_preact_relu False
# 7 conv2_block1_1_conv False
# 8 conv2_block1_1_bn False
# 9 conv2_block1_1_relu False
# 10 conv2_block1_2_pad False
# 11 conv2_block1_2_conv False
# 12 conv2_block1_2_bn False
# 13 conv2_block1_2_relu False
# 14 conv2_block1_0_conv False
# 15 conv2_block1_3_conv False
# 16 conv2_block1_out False
# 17 conv2_block2_preact_bn False
# 18 conv2_block2_preact_relu False
# 19 conv2_block2_1_conv False
# 20 conv2_block2_1_bn False
# 21 conv2_block2_1_relu False
# 22 conv2_block2_2_pad False
# 23 conv2_block2_2_conv False
# 24 conv2_block2_2_bn False
# 25 conv2_block2_2_relu False
# 26 conv2_block2_3_conv False
# 27 conv2_block2_out False
# 28 conv2_block3_preact_bn False
# 29 conv2_block3_preact_relu False
# 30 conv2_block3_1_conv False
# 31 conv2_block3_1_bn False
# 32 conv2_block3_1_relu False
# 33 conv2_block3_2_pad False
# 34 conv2_block3_2_conv False
# 35 conv2_block3_2_bn False
# 36 conv2_block3_2_relu False
# 37 max_pooling2d False
# 38 conv2_block3_3_conv False
# 39 conv2_block3_out False
# 40 conv3_block1_preact_bn False
# 41 conv3_block1_preact_relu False
# 42 conv3_block1_1_conv False
# 43 conv3_block1_1_bn False
# 44 conv3_block1_1_relu False
# 45 conv3_block1_2_pad False
# 46 conv3_block1_2_conv False
# 47 conv3_block1_2_bn False
# 48 conv3_block1_2_relu False
# 49 conv3_block1_0_conv False
# 50 conv3_block1_3_conv False
# 51 conv3_block1_out False
# 52 conv3_block2_preact_bn False
# 53 conv3_block2_preact_relu False
# 54 conv3_block2_1_conv False
# 55 conv3_block2_1_bn False
# 56 conv3_block2_1_relu False
# 57 conv3_block2_2_pad False
# 58 conv3_block2_2_conv False
# 59 conv3_block2_2_bn False
# 60 conv3_block2_2_relu False
# 61 conv3_block2_3_conv False
# 62 conv3_block2_out False
# 63 conv3_block3_preact_bn False
# 64 conv3_block3_preact_relu False
# 65 conv3_block3_1_conv False
# 66 conv3_block3_1_bn False
# 67 conv3_block3_1_relu False
# 68 conv3_block3_2_pad False
# 69 conv3_block3_2_conv False
# 70 conv3_block3_2_bn False
# 71 conv3_block3_2_relu False
# 72 conv3_block3_3_conv False
# 73 conv3_block3_out False
# 74 conv3_block4_preact_bn False
# 75 conv3_block4_preact_relu False
# 76 conv3_block4_1_conv False
# 77 conv3_block4_1_bn False
# 78 conv3_block4_1_relu False
# 79 conv3_block4_2_pad False
# 80 conv3_block4_2_conv False
# 81 conv3_block4_2_bn False
# 82 conv3_block4_2_relu False
# 83 max_pooling2d_1 False
# 84 conv3_block4_3_conv False
# 85 conv3_block4_out False
# 86 conv4_block1_preact_bn False
# 87 conv4_block1_preact_relu False
# 88 conv4_block1_1_conv False
# 89 conv4_block1_1_bn False
# 90 conv4_block1_1_relu False
# 91 conv4_block1_2_pad False
# 92 conv4_block1_2_conv False
# 93 conv4_block1_2_bn False
# 94 conv4_block1_2_relu False
# 95 conv4_block1_0_conv False
# 96 conv4_block1_3_conv False
# 97 conv4_block1_out False
# 98 conv4_block2_preact_bn False
# 99 conv4_block2_preact_relu False
# 100 conv4_block2_1_conv False
# 101 conv4_block2_1_bn False
# 102 conv4_block2_1_relu False
# 103 conv4_block2_2_pad False
# 104 conv4_block2_2_conv False
# 105 conv4_block2_2_bn False
# 106 conv4_block2_2_relu False
# 107 conv4_block2_3_conv False
# 108 conv4_block2_out False
# 109 conv4_block3_preact_bn False
# 110 conv4_block3_preact_relu False
# 111 conv4_block3_1_conv False
# 112 conv4_block3_1_bn False
# 113 conv4_block3_1_relu False
# 114 conv4_block3_2_pad False
# 115 conv4_block3_2_conv False
# 116 conv4_block3_2_bn False
# 117 conv4_block3_2_relu False
# 118 conv4_block3_3_conv False
# 119 conv4_block3_out False
# 120 conv4_block4_preact_bn False
# 121 conv4_block4_preact_relu False
# 122 conv4_block4_1_conv False
# 123 conv4_block4_1_bn False
# 124 conv4_block4_1_relu False
# 125 conv4_block4_2_pad False
# 126 conv4_block4_2_conv False
# 127 conv4_block4_2_bn False
# 128 conv4_block4_2_relu False
# 129 conv4_block4_3_conv False
# 130 conv4_block4_out False
# 131 conv4_block5_preact_bn False
# 132 conv4_block5_preact_relu False
# 133 conv4_block5_1_conv False
# 134 conv4_block5_1_bn False
# 135 conv4_block5_1_relu False
# 136 conv4_block5_2_pad False
# 137 conv4_block5_2_conv False
# 138 conv4_block5_2_bn False
# 139 conv4_block5_2_relu False
# 140 conv4_block5_3_conv False
# 141 conv4_block5_out False
# 142 conv4_block6_preact_bn False
# 143 conv4_block6_preact_relu False
# 144 conv4_block6_1_conv False
# 145 conv4_block6_1_bn False
# 146 conv4_block6_1_relu False
# 147 conv4_block6_2_pad False
# 148 conv4_block6_2_conv False
# 149 conv4_block6_2_bn False
# 150 conv4_block6_2_relu False
# 151 max_pooling2d_2 False
# 152 conv4_block6_3_conv False
# 153 conv4_block6_out False
# 154 conv5_block1_preact_bn True
# 155 conv5_block1_preact_relu True
# 156 conv5_block1_1_conv True
# 157 conv5_block1_1_bn True
# 158 conv5_block1_1_relu True
# 159 conv5_block1_2_pad True
# 160 conv5_block1_2_conv True
# 161 conv5_block1_2_bn True
# 162 conv5_block1_2_relu True
# 163 conv5_block1_0_conv True
# 164 conv5_block1_3_conv True
# 165 conv5_block1_out True
# 166 conv5_block2_preact_bn True
# 167 conv5_block2_preact_relu True
# 168 conv5_block2_1_conv True
# 169 conv5_block2_1_bn True
# 170 conv5_block2_1_relu True
# 171 conv5_block2_2_pad True
# 172 conv5_block2_2_conv True
# 173 conv5_block2_2_bn True
# 174 conv5_block2_2_relu True
# 175 conv5_block2_3_conv True
# 176 conv5_block2_out True
# 177 conv5_block3_preact_bn True
# 178 conv5_block3_preact_relu True
# 179 conv5_block3_1_conv True
# 180 conv5_block3_1_bn True
# 181 conv5_block3_1_relu True
# 182 conv5_block3_2_pad True
# 183 conv5_block3_2_conv True
# 184 conv5_block3_2_bn True
# 185 conv5_block3_2_relu True
# 186 conv5_block3_3_conv True
# 187 conv5_block3_out True
# 188 post_bn True
# 189 post_relu True

# %%
model.layers[4].summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 186, 186, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 90, 90, 64)   9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 92, 92, 64)   0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 45, 45, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 45, 45, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 45, 45, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 45, 45, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 45, 45, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 45, 45, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 45, 45, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 45, 45, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 45, 45, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 45, 45, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 45, 45, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 45, 45, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 45, 45, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 45, 45, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 23, 23, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 23, 23, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 23, 23, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 23, 23, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 23, 23, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 23, 23, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 23, 23, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 23, 23, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 23, 23, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 23, 23, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 23, 23, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 23, 23, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 23, 23, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 12, 12, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 12, 12, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 12, 12, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 12, 12, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 12, 12, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 12, 12, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 12, 12, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 12, 12, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 12, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 12, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 12, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 12, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 6, 6, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 6, 6, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 6, 6, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 6, 6, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 6, 6, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 6, 6, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 6, 6, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 6, 6, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 6, 6, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 6, 6, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 6, 6, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 6, 6, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 6, 6, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 6, 6, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 6, 6, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 14,970,880
# Non-trainable params: 8,593,920
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.Adam(learning_rate=1e-4)

model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 180, 180, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 180, 180, 3)      0
#  a)
#
#  resnet50v2 (Functional)     (None, 6, 6, 2048)        23564800
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dropout (Dropout)           (None, 73728)             0
#
#  dense (Dense)               (None, 18)                1327122
#
# =================================================================
# Total params: 24,891,922
# Trainable params: 16,298,002
# Non-trainable params: 8,593,920
# _________________________________________________________________

# %% [markdown]
# Let's add the same Keras callbacks as before and train the model:

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=8),

    keras.callbacks.ModelCheckpoint(
    filepath=os.path.join(dir_name, 'resnet_fine_tuning.h5'),
    monitor='val_loss',
    save_best_only=True,
    ),

    keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=5,
    )
]



history = model.fit(train_dataset,
                    epochs=100,
                    callbacks=callbacks_list,
                    validation_data=validation_dataset
                    )
# Out:
# Epoch 1/100
# 114/114 [==============================] - 65s 393ms/step - loss: 19.5123 - accuracy: 0.7931 - val_loss: 22.1089 - val_accuracy: 0.7877 - lr: 1.0000e-04
# Epoch 2/100
# Epoch 37/100
# 114/114 [==============================] - 38s 313ms/step - loss: 0.7525 - accuracy: 0.9627 - val_loss: 2.8352 - val_accuracy: 0.9099 - lr: 1.0000e-05
# Epoch 38/100
# 114/114 [==============================] - 44s 367ms/step - loss: 0.6139 - accuracy: 0.9630 - val_loss: 2.7457 - val_accuracy: 0.9111 - lr: 1.0000e-05
# Epoch 39/100
# 114/114 [==============================] - 38s 316ms/step - loss: 0.5892 - accuracy: 0.9663 - val_loss: 2.6297 - val_accuracy: 0.9148 - lr: 1.0000e-05
# Epoch 40/100
# 114/114 [==============================] - 37s 311ms/step - loss: 0.4655 - accuracy: 0.9654 - val_loss: 2.5871 - val_accuracy: 0.9136 - lr: 1.0000e-05
# Epoch 41/100
# 114/114 [==============================] - 38s 311ms/step - loss: 0.5447 - accuracy: 0.9672 - val_loss: 2.5163 - val_accuracy: 0.9210 - lr: 1.0000e-05
# Epoch 42/100
# 114/114 [==============================] - 38s 315ms/step - loss: 0.5354 - accuracy: 0.9687 - val_loss: 2.5086 - val_accuracy: 0.9222 - lr: 1.0000e-06
# Epoch 43/100
# 114/114 [==============================] - 39s 323ms/step - loss: 0.5526 - accuracy: 0.9664 - val_loss: 2.4771 - val_accuracy: 0.9222 - lr: 1.0000e-06

# %% [markdown]
# Plotting the Training and Validation Loss Curves:

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

i = np.argmax(val_acc)
x_min = epochs[i]
y_min = val_acc[i]
plt.plot(x_min, y_min,'g',marker='o', label="Maximum validation accuracy")

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

i = np.argmin(val_loss)
x_min = epochs[i]
y_min = val_loss[i]
plt.plot(x_min, y_min,'g',marker='o', label="Minimum validation loss")

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
#Evaluate the model on the training set
test_loss, test_acc = model.evaluate(test_dataset)

#Save the rusults in the history dictionary
history.history["test_loss"] = test_loss
history.history["test_accuracy"] = test_acc

print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 18/18 [==============================] - 9s 301ms/step - loss: 13.5653 - accuracy: 0.7212
# test_acc: 0.721222996711731
# test_loss: 13.565276145935059

# %% [markdown]
# # Fine tuning different layers

# %%
filepath=os.path.join(dir_name, 'ResNet_feature_extraction.h5')
model=keras.models.load_model(filepath)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 180, 180, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 180, 180, 3)      0
#  a)
#
#  resnet50v2 (Functional)     (None, 6, 6, 2048)        23564800
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dropout (Dropout)           (None, 73728)             0
#
#  dense (Dense)               (None, 18)                1327122
#
# =================================================================
# Total params: 24,891,922
# Trainable params: 1,327,122
# Non-trainable params: 23,564,800
# _________________________________________________________________

# %%
model.layers[4].summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 186, 186, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 90, 90, 64)   9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 92, 92, 64)   0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 45, 45, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 45, 45, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 45, 45, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 45, 45, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 45, 45, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 45, 45, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 45, 45, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 45, 45, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 45, 45, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 45, 45, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 45, 45, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 45, 45, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 45, 45, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 45, 45, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 23, 23, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 23, 23, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 23, 23, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 23, 23, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 23, 23, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 23, 23, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 23, 23, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 23, 23, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 23, 23, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 23, 23, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 23, 23, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 23, 23, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 23, 23, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 12, 12, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 12, 12, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 12, 12, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 12, 12, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 12, 12, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 12, 12, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 12, 12, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 12, 12, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 12, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 12, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 12, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 12, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 6, 6, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 6, 6, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 6, 6, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 6, 6, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 6, 6, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 6, 6, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 6, 6, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 6, 6, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 6, 6, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 6, 6, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 6, 6, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 6, 6, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 6, 6, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 6, 6, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 6, 6, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 0
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %% [markdown]
# Let's try fine tuning only the layers above the 187th:

# %%
model.layers[4].trainable = True
set_trainable = False

for layer in model.layers[4].layers[:187]:
  layer.trainable = False
for layer in model.layers[4].layers[187:]:
  layer.trainable = True

# %%
# Make sure you have frozen the correct layers
for i, layer in enumerate(model.layers[4].layers):
    print(i, layer.name, layer.trainable)
# Out:
# 0 input_1 False
# 1 conv1_pad False
# 2 conv1_conv False
# 3 pool1_pad False
# 4 pool1_pool False
# 5 conv2_block1_preact_bn False
# 6 conv2_block1_preact_relu False
# 7 conv2_block1_1_conv False
# 8 conv2_block1_1_bn False
# 9 conv2_block1_1_relu False
# 10 conv2_block1_2_pad False
# 11 conv2_block1_2_conv False
# 12 conv2_block1_2_bn False
# 13 conv2_block1_2_relu False
# 14 conv2_block1_0_conv False
# 15 conv2_block1_3_conv False
# 16 conv2_block1_out False
# 17 conv2_block2_preact_bn False
# 18 conv2_block2_preact_relu False
# 19 conv2_block2_1_conv False
# 20 conv2_block2_1_bn False
# 21 conv2_block2_1_relu False
# 22 conv2_block2_2_pad False
# 23 conv2_block2_2_conv False
# 24 conv2_block2_2_bn False
# 25 conv2_block2_2_relu False
# 26 conv2_block2_3_conv False
# 27 conv2_block2_out False
# 28 conv2_block3_preact_bn False
# 29 conv2_block3_preact_relu False
# 30 conv2_block3_1_conv False
# 31 conv2_block3_1_bn False
# 32 conv2_block3_1_relu False
# 33 conv2_block3_2_pad False
# 34 conv2_block3_2_conv False
# 35 conv2_block3_2_bn False
# 36 conv2_block3_2_relu False
# 37 max_pooling2d False
# 38 conv2_block3_3_conv False
# 39 conv2_block3_out False
# 40 conv3_block1_preact_bn False
# 41 conv3_block1_preact_relu False
# 42 conv3_block1_1_conv False
# 43 conv3_block1_1_bn False
# 44 conv3_block1_1_relu False
# 45 conv3_block1_2_pad False
# 46 conv3_block1_2_conv False
# 47 conv3_block1_2_bn False
# 48 conv3_block1_2_relu False
# 49 conv3_block1_0_conv False
# 50 conv3_block1_3_conv False
# 51 conv3_block1_out False
# 52 conv3_block2_preact_bn False
# 53 conv3_block2_preact_relu False
# 54 conv3_block2_1_conv False
# 55 conv3_block2_1_bn False
# 56 conv3_block2_1_relu False
# 57 conv3_block2_2_pad False
# 58 conv3_block2_2_conv False
# 59 conv3_block2_2_bn False
# 60 conv3_block2_2_relu False
# 61 conv3_block2_3_conv False
# 62 conv3_block2_out False
# 63 conv3_block3_preact_bn False
# 64 conv3_block3_preact_relu False
# 65 conv3_block3_1_conv False
# 66 conv3_block3_1_bn False
# 67 conv3_block3_1_relu False
# 68 conv3_block3_2_pad False
# 69 conv3_block3_2_conv False
# 70 conv3_block3_2_bn False
# 71 conv3_block3_2_relu False
# 72 conv3_block3_3_conv False
# 73 conv3_block3_out False
# 74 conv3_block4_preact_bn False
# 75 conv3_block4_preact_relu False
# 76 conv3_block4_1_conv False
# 77 conv3_block4_1_bn False
# 78 conv3_block4_1_relu False
# 79 conv3_block4_2_pad False
# 80 conv3_block4_2_conv False
# 81 conv3_block4_2_bn False
# 82 conv3_block4_2_relu False
# 83 max_pooling2d_1 False
# 84 conv3_block4_3_conv False
# 85 conv3_block4_out False
# 86 conv4_block1_preact_bn False
# 87 conv4_block1_preact_relu False
# 88 conv4_block1_1_conv False
# 89 conv4_block1_1_bn False
# 90 conv4_block1_1_relu False
# 91 conv4_block1_2_pad False
# 92 conv4_block1_2_conv False
# 93 conv4_block1_2_bn False
# 94 conv4_block1_2_relu False
# 95 conv4_block1_0_conv False
# 96 conv4_block1_3_conv False
# 97 conv4_block1_out False
# 98 conv4_block2_preact_bn False
# 99 conv4_block2_preact_relu False
# 100 conv4_block2_1_conv False
# 101 conv4_block2_1_bn False
# 102 conv4_block2_1_relu False
# 103 conv4_block2_2_pad False
# 104 conv4_block2_2_conv False
# 105 conv4_block2_2_bn False
# 106 conv4_block2_2_relu False
# 107 conv4_block2_3_conv False
# 108 conv4_block2_out False
# 109 conv4_block3_preact_bn False
# 110 conv4_block3_preact_relu False
# 111 conv4_block3_1_conv False
# 112 conv4_block3_1_bn False
# 113 conv4_block3_1_relu False
# 114 conv4_block3_2_pad False
# 115 conv4_block3_2_conv False
# 116 conv4_block3_2_bn False
# 117 conv4_block3_2_relu False
# 118 conv4_block3_3_conv False
# 119 conv4_block3_out False
# 120 conv4_block4_preact_bn False
# 121 conv4_block4_preact_relu False
# 122 conv4_block4_1_conv False
# 123 conv4_block4_1_bn False
# 124 conv4_block4_1_relu False
# 125 conv4_block4_2_pad False
# 126 conv4_block4_2_conv False
# 127 conv4_block4_2_bn False
# 128 conv4_block4_2_relu False
# 129 conv4_block4_3_conv False
# 130 conv4_block4_out False
# 131 conv4_block5_preact_bn False
# 132 conv4_block5_preact_relu False
# 133 conv4_block5_1_conv False
# 134 conv4_block5_1_bn False
# 135 conv4_block5_1_relu False
# 136 conv4_block5_2_pad False
# 137 conv4_block5_2_conv False
# 138 conv4_block5_2_bn False
# 139 conv4_block5_2_relu False
# 140 conv4_block5_3_conv False
# 141 conv4_block5_out False
# 142 conv4_block6_preact_bn False
# 143 conv4_block6_preact_relu False
# 144 conv4_block6_1_conv False
# 145 conv4_block6_1_bn False
# 146 conv4_block6_1_relu False
# 147 conv4_block6_2_pad False
# 148 conv4_block6_2_conv False
# 149 conv4_block6_2_bn False
# 150 conv4_block6_2_relu False
# 151 max_pooling2d_2 False
# 152 conv4_block6_3_conv False
# 153 conv4_block6_out False
# 154 conv5_block1_preact_bn False
# 155 conv5_block1_preact_relu False
# 156 conv5_block1_1_conv False
# 157 conv5_block1_1_bn False
# 158 conv5_block1_1_relu False
# 159 conv5_block1_2_pad False
# 160 conv5_block1_2_conv False
# 161 conv5_block1_2_bn False
# 162 conv5_block1_2_relu False
# 163 conv5_block1_0_conv False
# 164 conv5_block1_3_conv False
# 165 conv5_block1_out False
# 166 conv5_block2_preact_bn False
# 167 conv5_block2_preact_relu False
# 168 conv5_block2_1_conv False
# 169 conv5_block2_1_bn False
# 170 conv5_block2_1_relu False
# 171 conv5_block2_2_pad False
# 172 conv5_block2_2_conv False
# 173 conv5_block2_2_bn False
# 174 conv5_block2_2_relu False
# 175 conv5_block2_3_conv False
# 176 conv5_block2_out False
# 177 conv5_block3_preact_bn False
# 178 conv5_block3_preact_relu False
# 179 conv5_block3_1_conv False
# 180 conv5_block3_1_bn False
# 181 conv5_block3_1_relu False
# 182 conv5_block3_2_pad False
# 183 conv5_block3_2_conv False
# 184 conv5_block3_2_bn False
# 185 conv5_block3_2_relu False
# 186 conv5_block3_3_conv False
# 187 conv5_block3_out True
# 188 post_bn True
# 189 post_relu True

# %%
model.layers[4].summary()
# Out:
# Model: "resnet50v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 180, 180, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 186, 186, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 90, 90, 64)   9472        ['conv1_pad[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 92, 92, 64)   0           ['conv1_conv[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 45, 45, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 45, 45, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 45, 45, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 45, 45, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 45, 45, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 45, 45, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 45, 45, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 45, 45, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 45, 45, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 45, 45, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 45, 45, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 45, 45, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 45, 45, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 45, 45, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 45, 45, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 45, 45, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 45, 45, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 47, 47, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 23, 23, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 23, 23, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 23, 23, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 23, 23, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 23, 23, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 23, 23, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 23, 23, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 23, 23, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 23, 23, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 23, 23, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 23, 23, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 23, 23, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 23, 23, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 23, 23, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 23, 23, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 23, 23, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 23, 23, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 23, 23, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 23, 23, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 23, 23, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 25, 25, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 12, 12, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 12, 12, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 12, 12, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 12, 12, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 12, 12, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 12, 12, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 12, 12, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 12, 12, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 12, 12, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 12, 12, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 12, 12, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 12, 12, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 12, 12, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 12, 12, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 12, 12, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 12, 12, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 12, 12, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 12, 12, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 12, 12, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 12, 12, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 12, 12, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 12, 12, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 14, 14, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 6, 6, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 6, 6, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 6, 6, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 6, 6, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 6, 6, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 6, 6, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 6, 6, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 6, 6, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 6, 6, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 6, 6, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 6, 6, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 6, 6, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 6, 6, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 6, 6, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 6, 6, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 6, 6, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 8, 8, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 6, 6, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 6, 6, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 6, 6, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 6, 6, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 6, 6, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 6, 6, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 6, 6, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 23,564,800
# Trainable params: 4,096
# Non-trainable params: 23,560,704
# __________________________________________________________________________________________________

# %%
optimizer = keras.optimizers.Adam(learning_rate=1e-4)

model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 180, 180, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 180, 180, 3)      0
#  a)
#
#  resnet50v2 (Functional)     (None, 6, 6, 2048)        23564800
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dropout (Dropout)           (None, 73728)             0
#
#  dense (Dense)               (None, 18)                1327122
#
# =================================================================
# Total params: 24,891,922
# Trainable params: 1,331,218
# Non-trainable params: 23,560,704
# _________________________________________________________________

# %%
callbacks_list = [
    keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10),

    keras.callbacks.ModelCheckpoint(
    filepath=os.path.join(dir_name, 'resnet_fine_tuning.h5'),
    monitor='val_loss',
    save_best_only=True,
    ),

    keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=5,
    )
]



history = model.fit(train_dataset,
                    epochs=100,
                    callbacks=callbacks_list,
                    validation_data=validation_dataset
                    )
# Out:
# Epoch 1/100
# 114/114 [==============================] - 50s 334ms/step - loss: 15.4061 - accuracy: 0.8534 - val_loss: 25.3923 - val_accuracy: 0.8222 - lr: 1.0000e-04
# Epoch 2/100
# 114/114 [==============================] - 34s 284ms/step - loss: 13.2927 - accuracy: 0.8671 - val_loss: 25.8745 - val_accuracy: 0.8222 - lr: 1.0000e-04
# Epoch 3/100
# Epoch 20/100
# 114/114 [==============================] - 38s 310ms/step - loss: 11.5955 - accuracy: 0.8749 - val_loss: 23.6779 - val_accuracy: 0.8346 - lr: 1.0000e-04
# Epoch 21/100
# 114/114 [==============================] - 36s 297ms/step - loss: 12.1989 - accuracy: 0.8700 - val_loss: 23.7240 - val_accuracy: 0.8321 - lr: 1.0000e-04
# Epoch 22/100
# 114/114 [==============================] - 37s 306ms/step - loss: 12.8431 - accuracy: 0.8694 - val_loss: 23.4212 - val_accuracy: 0.8346 - lr: 1.0000e-04
# Epoch 23/100
# 114/114 [==============================] - 36s 292ms/step - loss: 12.7412 - accuracy: 0.8686 - val_loss: 23.4443 - val_accuracy: 0.8370 - lr: 1.0000e-04
# Epoch 24/100
# 114/114 [==============================] - 36s 301ms/step - loss: 13.2425 - accuracy: 0.8715 - val_loss: 23.4713 - val_accuracy: 0.8358 - lr: 1.0000e-04
# Epoch 25/100
# 114/114 [==============================] - 35s 291ms/step - loss: 13.1710 - accuracy: 0.8653 - val_loss: 23.4328 - val_accuracy: 0.8358 - lr: 1.0000e-04
# Epoch 26/100
# 114/114 [==============================] - 35s 290ms/step - loss: 13.6322 - accuracy: 0.8628 - val_loss: 23.5560 - val_accuracy: 0.8321 - lr: 1.0000e-04
# Epoch 27/100
# 114/114 [==============================] - 36s 301ms/step - loss: 13.8427 - accuracy: 0.8652 - val_loss: 23.8588 - val_accuracy: 0.8309 - lr: 1.0000e-04
# Epoch 28/100
# 114/114 [==============================] - 35s 291ms/step - loss: 13.4209 - accuracy: 0.8626 - val_loss: 23.8309 - val_accuracy: 0.8321 - lr: 1.0000e-05
# Epoch 29/100
# 114/114 [==============================] - 36s 295ms/step - loss: 12.4575 - accuracy: 0.8617 - val_loss: 23.8606 - val_accuracy: 0.8321 - lr: 1.0000e-05
# Epoch 30/100
# 114/114 [==============================] - 36s 303ms/step - loss: 13.9977 - accuracy: 0.8601 - val_loss: 23.9097 - val_accuracy: 0.8296 - lr: 1.0000e-05
# Epoch 31/100
# 114/114 [==============================] - 37s 305ms/step - loss: 12.3985 - accuracy: 0.8715 - val_loss: 23.8492 - val_accuracy: 0.8321 - lr: 1.0000e-05
# Epoch 32/100
# 114/114 [==============================] - 36s 301ms/step - loss: 13.0089 - accuracy: 0.8646 - val_loss: 23.7737 - val_accuracy: 0.8321 - lr: 1.0000e-05

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

i = np.argmax(val_acc)
x_min = epochs[i]
y_min = val_acc[i]
plt.plot(x_min, y_min,'g',marker='o', label="Maximum validation accuracy")

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

i = np.argmin(val_loss)
x_min = epochs[i]
y_min = val_loss[i]
plt.plot(x_min, y_min,'g',marker='o', label="Minimum validation loss")

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
#Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_dataset)

#Save the rusults in the history dictionary
history.history["test_loss"] = test_loss
history.history["test_accuracy"] = test_acc

print('test_acc:', test_acc)
print('test_loss:', test_loss)
# Out:
# 18/18 [==============================] - 10s 332ms/step - loss: 75.0416 - accuracy: 0.6394
# test_acc: 0.6393885016441345
# test_loss: 75.04159545898438
