# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import os
from tqdm import tqdm, tqdm_notebook
import random
from google.colab import drive
from google.colab import files
import shutil

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from numpy.random import seed
import pickle
seed(1)
tf.random.set_seed(1)

import matplotlib.pyplot as plt

# %%
#Function to print the training plot
def trainPlot(history):
  acc = history['accuracy']
  val_acc = history['val_accuracy']
  loss = history['loss']
  val_loss = history['val_loss']

  epochs = range(len(acc))

  plt.plot(epochs, acc, 'r', label='Training accuracy')
  plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.figure()

  plt.plot(epochs, loss, 'r', label='Training loss')
  plt.plot(epochs, val_loss, 'b', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

  plt.show()

# %%
# mount drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Retrieve the training histories of the two models

# %%
root_path = "/content/drive/Shareddrives/[Deep Learning Project]"
dir_name = os.path.join(root_path, "Models")
modelBalanced = keras.models.load_model(dir_name+ '/'+'model_balanced_training_set.h5')
model = keras.models.load_model(dir_name+ '/'+'artistsRecognition1.h5')

with open(os.path.join(dir_name,'trainHistory'), "rb") as file_pi:
    history = pickle.load(file_pi)

with open(os.path.join(dir_name,'trainBalancedHistory'), "rb") as file_pi:
    historyBalanced = pickle.load(file_pi)

# %%
#Plot of the model trained with weights
trainPlot(history)

# %%
#Plot of the model trained with the balanced dataset
trainPlot(historyBalanced)

# %% [markdown]
# Test accuracy of the model trained with class weights

# %%
history["test_accuracy"]
# Out:
# 0.42446044087409973

# %% [markdown]
# Test accuracy of the model trained with the balanced dataset

# %%
historyBalanced["test_accuracy"]
# Out:
# 0.45047488808631897

# %% [markdown]
# Comparing the two models by putting together their relative plots

# %%
acc= history['accuracy']
acc_bal = historyBalanced['accuracy']

val_acc = history['val_accuracy']
val_acc_bal = historyBalanced['val_accuracy']

loss = history['loss']
loss_bal = historyBalanced['loss']

val_loss = history['val_loss']
val_loss_bal = historyBalanced['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, acc_bal, 'b', label='Training balanced accuracy')
plt.title('Training accuracy on unbalanced and balanced dataset')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, loss_bal, 'b', label='Training balanced loss')
plt.title('Training loss on unbalanced and balanced dataset')
plt.legend()

plt.figure()

plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.plot(epochs, val_acc_bal, 'b', label='Validation balanced accuracy')
plt.title('Validation accuracy on unbalanced and balanced dataset')
plt.legend()

plt.figure()

plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.plot(epochs, val_loss_bal, 'b', label='Validation balanced loss')
plt.title('Validation loss on unbalanced and balanced dataset')
plt.legend()

plt.figure()

plt.show()

# %% [markdown]
# The conclusions are discussed in the report
